# %%
# pip install summarytools

# %%
import pandas as pd
from summarytools import dfSummary

# %%
df = pd.read_csv('/content/Global_Landslide_Catalog_Export.csv')

# %%
df.head()
# Out:
#    source_name                                        source_link  event_id  \
# 0          AGU  https://blogs.agu.org/landslideblog/2008/10/14...       684
# 1    Oregonian  http://www.oregonlive.com/news/index.ssf/2009/...       956
# 2     CBS News  https://www.cbsnews.com/news/dozens-missing-af...       973
# 3      Reuters  https://in.reuters.com/article/idINIndia-41450...      1067
# 4  The Freeman  http://www.philstar.com/cebu-news/621414/lands...      2603
#
#                event_date  event_time  \
# 0  08/01/2008 12:00:00 AM         NaN
# 1  01/02/2009 02:00:00 AM         NaN
# 2  01/19/2007 12:00:00 AM         NaN
# 3  07/31/2009 12:00:00 AM         NaN
# 4  10/16/2010 12:00:00 PM         NaN
#
#                                          event_title  \
# 0      Sigou Village, Loufan County, Shanxi Province
# 1                                Lake Oswego, Oregon
# 2  San Ramon district, 195 miles northeast of the...
# 3                                   Dailekh district
# 4                    sitio Bakilid in barangay Lahug
#
#                                    event_description  \
# 0  occurred early in morning, 11 villagers buried...
# 1  Hours of heavy rain are to blame for an overni...
# 2  (CBS/AP) At least 10 people died and as many a...
# 3  One person was killed in Dailekh district, pol...
# 4  Another landslide in sitio Bakilid in barangay...
#
#                                 location_description location_accuracy  \
# 0      Sigou Village, Loufan County, Shanxi Province           unknown
# 1                                Lake Oswego, Oregon               5km
# 2  San Ramon district, 195 miles northeast of the...              10km
# 3                                   Dailekh district           unknown
# 4                    sitio Bakilid in barangay Lahug               5km
#
#   landslide_category  ... country_code admin_division_name  \
# 0          landslide  ...           CN             Shaanxi
# 1           mudslide  ...           US              Oregon
# 2          landslide  ...           PE               Junín
# 3          landslide  ...           NP         Mid Western
# 4          landslide  ...           PH     Central Visayas
#
#   admin_division_population  gazeteer_closest_point  gazeteer_distance  \
# 0                       0.0                Jingyang           41.02145
# 1                   36619.0             Lake Oswego            0.60342
# 2                   14708.0               San Ramón            0.85548
# 3                   20908.0                 Dailekh            0.75395
# 4                  798634.0               Cebu City            2.02204
#
#            submitted_date            created_date        last_edited_date  \
# 0  04/01/2014 12:00:00 AM  11/20/2017 03:17:00 PM  02/15/2018 03:51:00 PM
# 1  04/01/2014 12:00:00 AM  11/20/2017 03:17:00 PM  02/15/2018 03:51:00 PM
# 2  04/01/2014 12:00:00 AM  11/20/2017 03:17:00 PM  02/15/2018 03:51:00 PM
# 3  04/01/2014 12:00:00 AM  11/20/2017 03:17:00 PM  02/15/2018 03:51:00 PM
# 4  04/01/2014 12:00:00 AM  11/20/2017 03:17:00 PM  02/15/2018 03:51:00 PM
#
#   longitude  latitude
# 0  107.4500   32.5625
# 1 -122.6630   45.4200
# 2  -75.3587  -11.1295
# 3   81.7080   28.8378
# 4  123.8978   10.3336
#
# [5 rows x 31 columns]

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_5c664 thead>tr>th {
#   text-align: left;
# }
# #T_5c664_row0_col0, #T_5c664_row1_col0, #T_5c664_row2_col0, #T_5c664_row3_col0, #T_5c664_row4_col0, #T_5c664_row5_col0, #T_5c664_row6_col0, #T_5c664_row7_col0, #T_5c664_row8_col0, #T_5c664_row9_col0, #T_5c664_row10_col0, #T_5c664_row11_col0, #T_5c664_row12_col0, #T_5c664_row13_col0, #T_5c664_row14_col0, #T_5c664_row15_col0, #T_5c664_row16_col0, #T_5c664_row17_col0, #T_5c664_row18_col0, #T_5c664_row19_col0, #T_5c664_row20_col0, #T_5c664_row21_col0, #T_5c664_row22_col0, #T_5c664_row23_col0, #T_5c664_row24_col0, #T_5c664_row25_col0, #T_5c664_row26_col0, #T_5c664_row27_col0, #T_5c664_row28_col0, #T_5c664_row29_col0, #T_5c664_row30_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_5c664_row0_col1, #T_5c664_row1_col1, #T_5c664_row2_col1, #T_5c664_row3_col1, #T_5c664_row4_col1, #T_5c664_row5_col1, #T_5c664_row6_col1, #T_5c664_row7_col1, #T_5c664_row8_col1, #T_5c664_row9_col1, #T_5c664_row10_col1, #T_5c664_row11_col1, #T_5c664_row12_col1, #T_5c664_row13_col1, #T_5c664_row14_col1, #T_5c664_row15_col1, #T_5c664_row16_col1, #T_5c664_row17_col1, #T_5c664_row18_col1, #T_5c664_row19_col1, #T_5c664_row20_col1, #T_5c664_row21_col1, #T_5c664_row22_col1, #T_5c664_row23_col1, #T_5c664_row24_col1, #T_5c664_row25_col1, #T_5c664_row26_col1, #T_5c664_row27_col1, #T_5c664_row28_col1, #T_5c664_row29_col1, #T_5c664_row30_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_5c664_row0_col2, #T_5c664_row1_col2, #T_5c664_row2_col2, #T_5c664_row3_col2, #T_5c664_row4_col2, #T_5c664_row5_col2, #T_5c664_row6_col2, #T_5c664_row7_col2, #T_5c664_row8_col2, #T_5c664_row9_col2, #T_5c664_row10_col2, #T_5c664_row11_col2, #T_5c664_row12_col2, #T_5c664_row13_col2, #T_5c664_row14_col2, #T_5c664_row15_col2, #T_5c664_row16_col2, #T_5c664_row17_col2, #T_5c664_row18_col2, #T_5c664_row19_col2, #T_5c664_row20_col2, #T_5c664_row21_col2, #T_5c664_row22_col2, #T_5c664_row23_col2, #T_5c664_row24_col2, #T_5c664_row25_col2, #T_5c664_row26_col2, #T_5c664_row27_col2, #T_5c664_row28_col2, #T_5c664_row29_col2, #T_5c664_row30_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_5c664_row0_col3, #T_5c664_row1_col3, #T_5c664_row2_col3, #T_5c664_row3_col3, #T_5c664_row4_col3, #T_5c664_row5_col3, #T_5c664_row6_col3, #T_5c664_row7_col3, #T_5c664_row8_col3, #T_5c664_row9_col3, #T_5c664_row10_col3, #T_5c664_row11_col3, #T_5c664_row12_col3, #T_5c664_row13_col3, #T_5c664_row14_col3, #T_5c664_row15_col3, #T_5c664_row16_col3, #T_5c664_row17_col3, #T_5c664_row18_col3, #T_5c664_row19_col3, #T_5c664_row20_col3, #T_5c664_row21_col3, #T_5c664_row22_col3, #T_5c664_row23_col3, #T_5c664_row24_col3, #T_5c664_row25_col3, #T_5c664_row26_col3, #T_5c664_row27_col3, #T_5c664_row28_col3, #T_5c664_row29_col3, #T_5c664_row30_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_5c664_row0_col4, #T_5c664_row1_col4, #T_5c664_row2_col4, #T_5c664_row3_col4, #T_5c664_row4_col4, #T_5c664_row5_col4, #T_5c664_row6_col4, #T_5c664_row7_col4, #T_5c664_row8_col4, #T_5c664_row9_col4, #T_5c664_row10_col4, #T_5c664_row11_col4, #T_5c664_row12_col4, #T_5c664_row13_col4, #T_5c664_row14_col4, #T_5c664_row15_col4, #T_5c664_row16_col4, #T_5c664_row17_col4, #T_5c664_row18_col4, #T_5c664_row19_col4, #T_5c664_row20_col4, #T_5c664_row21_col4, #T_5c664_row22_col4, #T_5c664_row23_col4, #T_5c664_row24_col4, #T_5c664_row25_col4, #T_5c664_row26_col4, #T_5c664_row27_col4, #T_5c664_row28_col4, #T_5c664_row29_col4, #T_5c664_row30_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_5c664_row0_col5, #T_5c664_row1_col5, #T_5c664_row2_col5, #T_5c664_row3_col5, #T_5c664_row4_col5, #T_5c664_row5_col5, #T_5c664_row6_col5, #T_5c664_row7_col5, #T_5c664_row8_col5, #T_5c664_row9_col5, #T_5c664_row10_col5, #T_5c664_row11_col5, #T_5c664_row12_col5, #T_5c664_row13_col5, #T_5c664_row14_col5, #T_5c664_row15_col5, #T_5c664_row16_col5, #T_5c664_row17_col5, #T_5c664_row18_col5, #T_5c664_row19_col5, #T_5c664_row20_col5, #T_5c664_row21_col5, #T_5c664_row22_col5, #T_5c664_row23_col5, #T_5c664_row24_col5, #T_5c664_row25_col5, #T_5c664_row26_col5, #T_5c664_row27_col5, #T_5c664_row28_col5, #T_5c664_row29_col5, #T_5c664_row30_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_5c664" class="dataframe">
#   <caption><strong>Data Frame Summary</strong><br>df<br>Dimensions: 11,033 x 31<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_5c664_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_5c664_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_5c664_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_5c664_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_5c664_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_5c664_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5c664_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_5c664_row0_col1" class="data row0 col1" ><strong>source_name</strong><br>[object]</td>
#       <td id="T_5c664_row0_col2" class="data row0 col2" >1. Oregon DOT<br>2. maps.google.com<br>3. thehimalayantimes<br>4. news.xinhuanet<br>5. newsinfo.inquirer<br>6. thejakartapost<br>7. ibnlive.in<br>8. Times of India<br>9. The Jakarta Post<br>10. The Himalayan Times<br>11. other</td>
#       <td id="T_5c664_row0_col3" class="data row0 col3" >768 (7.0%)<br>104 (0.9%)<br>75 (0.7%)<br>74 (0.7%)<br>71 (0.6%)<br>59 (0.5%)<br>57 (0.5%)<br>47 (0.4%)<br>46 (0.4%)<br>43 (0.4%)<br>9,689 (87.8%)</td>
#       <td id="T_5c664_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_5c664_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_5c664_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_5c664_row1_col1" class="data row1 col1" ><strong>source_link</strong><br>[object]</td>
#       <td id="T_5c664_row1_col2" class="data row1 col2" >1. nan<br>2. http://maps.google.com.br/maps<br>3. http://www.thelevisalazer.com/<br>4. http://www.portal.gsi.gov.in/p<br>5. http://landslides.usgs.gov/rec<br>6. http://livenews.co.nz/2013/09/<br>7. http://news.pia.gov.ph/index.p<br>8. http://www.thedenverchannel.co<br>9. http://businessmirror.com.ph/h<br>10. http://www.cdrc-phil.com/cordi<br>11. other</td>
#       <td id="T_5c664_row1_col3" class="data row1 col3" >846 (7.7%)<br>104 (0.9%)<br>13 (0.1%)<br>13 (0.1%)<br>12 (0.1%)<br>12 (0.1%)<br>12 (0.1%)<br>11 (0.1%)<br>11 (0.1%)<br>11 (0.1%)<br>9,988 (90.5%)</td>
#       <td id="T_5c664_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_5c664_row1_col5" class="data row1 col5" >846<br>(7.7%)</td>
#     </tr>
#     <tr>
#       <td id="T_5c664_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_5c664_row2_col1" class="data row2 col1" ><strong>event_id</strong><br>[int64]</td>
#       <td id="T_5c664_row2_col2" class="data row2 col2" >Mean (sd) : 5599.0 (3249.2)<br>min < med < max:<br>1.0 < 5563.0 < 11221.0<br>IQR (CV) : 5650.0 (1.7)</td>
#       <td id="T_5c664_row2_col3" class="data row2 col3" >11,033 distinct values</td>
#       <td id="T_5c664_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_5c664_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_5c664_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_5c664_row3_col1" class="data row3 col1" ><strong>event_date</strong><br>[object]</td>
#       <td id="T_5c664_row3_col2" class="data row3 col2" >1. 04/06/2010 12:00:00 AM<br>2. 12/12/2010 12:00:00 AM<br>3. 07/03/2011 12:00:0

# %%
df.drop(['event_date','event_id','event_title','event_description','source_name','source_link','event_time','submitted_date','location_description',
         'created_date','last_edited_date','landslide_setting','storm_name','photo_link',
         'notes',"event_import_source","event_import_id",'location_accuracy'], axis=1, inplace=True)

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_954a1 thead>tr>th {
#   text-align: left;
# }
# #T_954a1_row0_col0, #T_954a1_row1_col0, #T_954a1_row2_col0, #T_954a1_row3_col0, #T_954a1_row4_col0, #T_954a1_row5_col0, #T_954a1_row6_col0, #T_954a1_row7_col0, #T_954a1_row8_col0, #T_954a1_row9_col0, #T_954a1_row10_col0, #T_954a1_row11_col0, #T_954a1_row12_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_954a1_row0_col1, #T_954a1_row1_col1, #T_954a1_row2_col1, #T_954a1_row3_col1, #T_954a1_row4_col1, #T_954a1_row5_col1, #T_954a1_row6_col1, #T_954a1_row7_col1, #T_954a1_row8_col1, #T_954a1_row9_col1, #T_954a1_row10_col1, #T_954a1_row11_col1, #T_954a1_row12_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_954a1_row0_col2, #T_954a1_row1_col2, #T_954a1_row2_col2, #T_954a1_row3_col2, #T_954a1_row4_col2, #T_954a1_row5_col2, #T_954a1_row6_col2, #T_954a1_row7_col2, #T_954a1_row8_col2, #T_954a1_row9_col2, #T_954a1_row10_col2, #T_954a1_row11_col2, #T_954a1_row12_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_954a1_row0_col3, #T_954a1_row1_col3, #T_954a1_row2_col3, #T_954a1_row3_col3, #T_954a1_row4_col3, #T_954a1_row5_col3, #T_954a1_row6_col3, #T_954a1_row7_col3, #T_954a1_row8_col3, #T_954a1_row9_col3, #T_954a1_row10_col3, #T_954a1_row11_col3, #T_954a1_row12_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_954a1_row0_col4, #T_954a1_row1_col4, #T_954a1_row2_col4, #T_954a1_row3_col4, #T_954a1_row4_col4, #T_954a1_row5_col4, #T_954a1_row6_col4, #T_954a1_row7_col4, #T_954a1_row8_col4, #T_954a1_row9_col4, #T_954a1_row10_col4, #T_954a1_row11_col4, #T_954a1_row12_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_954a1_row0_col5, #T_954a1_row1_col5, #T_954a1_row2_col5, #T_954a1_row3_col5, #T_954a1_row4_col5, #T_954a1_row5_col5, #T_954a1_row6_col5, #T_954a1_row7_col5, #T_954a1_row8_col5, #T_954a1_row9_col5, #T_954a1_row10_col5, #T_954a1_row11_col5, #T_954a1_row12_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_954a1" class="dataframe">
#   <caption><strong>Data Frame Summary</strong><br>df<br>Dimensions: 11,033 x 13<br>Duplicates: 30</caption>
#   <thead>
#     <tr>
#       <th id="T_954a1_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_954a1_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_954a1_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_954a1_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_954a1_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_954a1_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_954a1_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_954a1_row0_col1" class="data row0 col1" ><strong>landslide_category</strong><br>[object]</td>
#       <td id="T_954a1_row0_col2" class="data row0 col2" >1. landslide<br>2. mudslide<br>3. rock_fall<br>4. complex<br>5. debris_flow<br>6. other<br>7. unknown<br>8. riverbank_collapse<br>9. snow_avalanche<br>10. translational_slide<br>11. other</td>
#       <td id="T_954a1_row0_col3" class="data row0 col3" >7,648 (69.3%)<br>2,100 (19.0%)<br>671 (6.1%)<br>232 (2.1%)<br>194 (1.8%)<br>68 (0.6%)<br>38 (0.3%)<br>37 (0.3%)<br>15 (0.1%)<br>9 (0.1%)<br>21 (0.2%)</td>
#       <td id="T_954a1_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_954a1_row0_col5" class="data row0 col5" >1<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_954a1_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_954a1_row1_col1" class="data row1 col1" ><strong>landslide_trigger</strong><br>[object]</td>
#       <td id="T_954a1_row1_col2" class="data row1 col2" >1. downpour<br>2. rain<br>3. unknown<br>4. continuous_rain<br>5. tropical_cyclone<br>6. snowfall_snowmelt<br>7. monsoon<br>8. mining<br>9. earthquake<br>10. construction<br>11. other</td>
#       <td id="T_954a1_row1_col3" class="data row1 col3" >4,680 (42.4%)<br>2,592 (23.5%)<br>1,691 (15.3%)<br>748 (6.8%)<br>561 (5.1%)<br>135 (1.2%)<br>129 (1.2%)<br>93 (0.8%)<br>89 (0.8%)<br>82 (0.7%)<br>233 (2.1%)</td>
#       <td id="T_954a1_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_954a1_row1_col5" class="data row1 col5" >23<br>(0.2%)</td>
#     </tr>
#     <tr>
#       <td id="T_954a1_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_954a1_row2_col1" class="data row2 col1" ><strong>landslide_size</strong><br>[object]</td>
#       <td id="T_954a1_row2_col2" class="data row2 col2" >1. medium<br>2. small<br>3. unknown<br>4. large<br>5. very_large<br>6. nan<br>7. catastrophic</td>
#       <td id="T_954a1_row2_col3" class="data row2 col3" >6,551 (59.4%)<br>2,767 (25.1%)<br>851 (7.7%)<br>750 (6.8%)<br>102 (0.9%)<br>9 (0.1%)<br>3 (0.0%)</td>
#       <td id="T_954a1_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_954a1_row2_col5" class="data row2 col5" >9<br>(0.1%)</td>
#     </tr>
#     <tr>
#       <td id="T_954a1_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_954a1_row3_col1" class="data row3 col1" ><strong>fatality_count</strong><br>[float64]</td>
#       <td id="T_954a1_row3_col2" class="data row3 col2" >Mean (sd) : 3.2 (59.9)<br>min < med < max:<br>0.0 < 0.0 < 5000.0<br>IQR (CV) : 1.0 (0.1)</td>
#       <td id="T_954a1_row3_col3" class="data row3 col3" >105 distinct values</td>
#       <td id="T_954a1_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_954a1_row3_col5" class="data row3 col5" >1,385<br>(12.6%)</td>
#     </tr>
#     <tr>
#       <td id="T_954a1_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_954a1_row4_col1" class="data row4 col1" ><strong>injury_count</strong><br>[float64]</td>
#       <td id="T_954a1_row4_col2" class="data row4 col2" >Mean (sd) : 0.8 (8.5)<br>min < med < max:<br>0.0 < 0.0 < 374.0<br>IQR (CV) : 0.0 (0.1)</td>
#       <td id="T_954a1_row4_col3" class="data row4 col3" >42 distinct values</td>
#       <td id="T_954a1_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_954a1_row4_col5" class="data row4 col5" >5,674<br>(51.4%)</td>
#     </tr>
#     <tr>
#       <td id="T_954a1_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_954a1_row5_col1" class="data row5 col1" ><strong>country_name</strong><br>[object]</td>
#       <td id="T_954a1_row5_col2" class="data row5 col2" >1. United States<br>2. nan<br>3. India<br>4. Philippines<br>5. Nepal<br>6. China<br>7. Indonesia<br>8. United Kingdom<br>9. Brazil<br>10. Canada<br>11. other</td>
#       <td id="T_954a1_row5_col3" class="data row5 col3" >2,992 (27.1%)<br>1,562 (14.2%)<br>1,265 (11.5%)<br>675 (6.1%)<br>481 (4.4%)<br>426 (3.9%)<br>355 (3.2%)<br>229 (2.1%)<br>214 (1.9%)<br>174 (1.6%)<br>2,660 (24.1%)</td>
#       <td id="T_954a1_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_954a1_row5_col5" class="data row5 col5" >1,562<br>(14.2%)</td>
#     </tr>
#     <tr>
#       <td id="T_954a1_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_954a1_row6_col1" class="data row6 col1" ><strong>country_code</strong><br>[object]</td>
#       <td id="T_954a1_row6_col2" class="data row6 col2" >1. US<br>2. nan<br>3. IN<br>4. PH<br>5. NP<br>6. CN<br>7. ID<br>8. GB<br>9. BR<br>10. CA<br>11. other</td>
#       <td id="T_954a1_row6_col3" class="data row6 col3" >2,992 (27.1%)<br>1,564 (14.2%)<br>1,265 (11.5%)<br>675 (6.1%)<br>481 (4.4%)<br>426 (3.9%)<br>355 (3.2%)<br>229 (2.1%)<br>214 (1.9%)<br>174 (1.6%)<br>2,658 (24.1%)</td>
#       <td id="T_954a1_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_954a1_row6_col5" class="data row6 col5"

# %%
df.isnull().sum()
# Out:
# landslide_category              1
# landslide_trigger              23
# landslide_size                  9
# fatality_count               1385
# injury_count                 5674
# country_name                 1562
# country_code                 1564
# admin_division_name          1637
# admin_division_population    1562
# gazeteer_closest_point       1563
# gazeteer_distance            1562
# longitude                       0
# latitude                        0
# dtype: int64

# %%
# df['event_description'].value_counts()

# %%
df.to_csv('new_data.csv')
